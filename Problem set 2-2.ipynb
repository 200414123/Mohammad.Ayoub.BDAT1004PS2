# %% [markdown]
# # Question 1
#
# Consider the following Python module:
#
# a = 0
#
# def b():
# global a
# a = c(a)
#
# def c(a):
# return a + 2
#
# After importing the module into the interpreter, you execute:
#
# >>>	b()
# >>>	b()
# >>>	b()
#
# >>>	a
# ?

# %% [markdown]
# In the first call to function b()
# a=c(a)=a+2=0+2=2
#
# In thsecond call to function b()
# a = c(a)=a+2=2+2 = 4
#
# In the third call to function b()
# a = c(a)=a+2=4+2 = 6

# %% [markdown]
# # Question 2)
#
# Function fileLength(), given to you, takes the name of a file as input and returns the length of the file:
#
# >>>	fileLength('midterm.py')
# 284
#
# >>>	fileLength('idterm.py') Traceback (most recent call last):
#
# File "<pyshell#34>", line 1, in <module> fileLength('idterm.py')
#
# File "/Users/me/midterm.py", line 3, in fileLength infile = open(filename)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'idterm.py'
#
# As shown above, if the file cannot be found by the interpreter or if it cannot be read as a text file, an exception will be raised. Modify function fileLength() so that a friendly message is printed instead:
#
# >>>	fileLength('midterm.py')
# 358
#
# >>>	fileLength('idterm.py') File idterm.py not found.

# %%
def fileLength(file):
      try:
        infile = open(file)
        print (len(infile.read()))
      except FileNotFoundError:
          print('File {} not found.'.format(file))
            
            
fileLength('idterm.py')
# Out:
# File idterm.py not found.

# %% [markdown]
# # Question 3
#
# Write a class named Marsupial that can be used as shown below:
#
# >>>	m = Marsupial()
# >>>	m.put_in_pouch('doll')
# >>>	m.put_in_pouch('firetruck')
#
# >>>	m.put_in_pouch('kitten')
#
# >>>	m.pouch_contents() ['doll', 'firetruck', 'kitten']
#
#
# Now write a class named Kangaroo as a subclass of Marsupial that inherits all the attributes of Marsupial and also:
#
# a. extends the Marsupial __init__ constructor to take, as input, the coordinates x and y of the Kangaroo object,
#
# b. supports method jump that takes number values dx and dy as input and moves the kangaroo by dx units along the x-axis and by dy units along the y-axis, and
#
# c. overloads the __str__ operator so it behaves as shown below.

# %%
class Marsupial:
    def __init__(self):
        self.dict=[]
    
    def _str_(self):
        return ( "I am a Kangaroo located at coordinates ("+str(self.dx)+","+str(self.dy)+")")
    
    def put_in_pouch(self,ob):
        self.dict.append(ob)
        
    def pouch_contents(self):
        print(self.dict)
        
     

class Kangaroo(Marsupial):
    def __init__(self,x,y):
        Marsupial.__init__(self)
        self.dx=x
        self.dy=y
    
    def __str__(self):
        s = "I am a Kangaroo located at coordinates ("+str(self.dx)+","+str(self.dy)+")"
        return "(%s)"%(s) 
    
    def jump(self,x,y):
        self.dx +=x
        self.dy +=y
  

k = Kangaroo(0,0)
print(k)
# Out:
# (I am a Kangaroo located at coordinates (0,0))

# %% [markdown]
# # Question 4:
#
# Implement a new GUI class App that combines user-defined tkinter widget classes Calculator and Mortgage displayed below: (This question can be done using a .py file)

# %%
from tkinter import *
import math


class Calculator(Frame):

    def pressHandler(self,num):
        self.expression = self.expression + str(num)
        self.equation.set(self.expression)

   

    def equalHandler(self):
        try:
            total = str(eval(self.expression))
            self.equation.set(total)
            self.expression = total
        except:
            self.equation.set("Make an error here")
           
    def plusEqualHandler(self):
        try:
            total = str(eval(self.expression))
            self.equation.set(total)
            self.expression = total+'+'
        except:
            self.equation.set(" error ")
            self.expression = ""

    def rootHandler(self):

        try:

            total = str(math.sqrt(eval(self.expression)))

            self.equation.set(total)

            self.expression = total

        except:

            self.equation.set(" error ")
            self.expression = ""

    def squareHandler(self):
        try:

            total = str(eval(self.expression)**2)

            self.equation.set(total)



        except:

            self.equation.set(" error ")
            self.expression = ""
    
    def MCHandler(self):
        self.Memory=0

    def MplusHandler(self):
        try:

            total = eval(self.expression)
            self.Memory = self.Memory + total
            self.expression = ''  

        except:
            self.equation.set(" error ")
            self.expression = ""

    def MminusHandler(self):
        try:
            total = eval(self.expression)
            self.Memory = self.Memory - total
            self.expression = ''  

        except:
            self.equation.set(" error ")
            self.expression = ""

    def MRHandler(self):
        try:
            self.equation.set(self.Memory)

        except:
            self.equation.set(" error ")
            self.expression = ""

    def clear(self):
        self.expression = ""
        self.equation.set("")

    def __init__(self, parent):
        Frame.__init__(self, parent)
        self.expression = ""
        self.Memory = 0
        self.configure(background="white", padx=10, pady=10)
        self.DrawWidgets()

    def DrawWidgets(self):
        self.equation = StringVar()

        self.expression_field = Entry(self, textvariable=self.equation,bg='gray')
        self.expression_field.grid(columnspan=4, ipadx=52,)

        self.equation.set('')

        button1 = Button(self, text=' 1 ', fg='black', bg='white',
                         command=lambda: self.pressHandler(1), height=1, width=3)
        button1.grid(row=6, column=0)

        button2 = Button(self, text=' 2 ', fg='black', bg='white',
                         command=lambda: self.pressHandler(2), height=1, width=3)
        button2.grid(row=6, column=1)

        button3 = Button(self, text=' 3 ', fg='black', bg='white',
                         command=lambda: self.pressHandler(3), height=1, width=3)
        button3.grid(row=6, column=2)

        button4 = Button(self, text=' 4 ', fg='black', bg='white',
                         command=lambda: self.pressHandler(4), height=1, width=3)
        button4.grid(row=5, column=0)

        button5 = Button(self, text=' 5 ', fg='black', bg='white',
                         command=lambda: self.pressHandler(5), height=1, width=3)
        button5.grid(row=5, column=1)

        button6 = Button(self, text=' 6 ', fg='black', bg='white',
                         command=lambda: self.pressHandler(6), height=1, width=3)
        button6.grid(row=5, column=2)

        button7 = Button(self, text=' 7 ', fg='black', bg='white',
                         command=lambda: self.pressHandler(7), height=1, width=3)
        button7.grid(row=4, column=0)

        button8 = Button(self, text=' 8 ', fg='black', bg='white',
                         command=lambda: self.pressHandler(8), height=1, width=3)
        button8.grid(row=4, column=1)

        button9 = Button(self, text=' 9 ', fg='black', bg='white',
                         command=lambda: self.pressHandler(9), height=1, width=3)
        button9.grid(row=4, column=2)

        button0 = Button(self, text=' 0 ', fg='black', bg='white',
                         command=lambda: self.pressHandler(0), height=1, width=3)
        button0.grid(row=7, column=0)

        plus = Button(self, text=' + ', fg='black', bg='white',
                      command=lambda: self.pressHandler("+"), height=1, width=3)
        plus.grid(row=3, column=3)

        minus = Button(self, text=' - ', fg='black', bg='white',
                       command=lambda: self.pressHandler("-"), height=1, width=3)
        minus.grid(row=4, column=3)

        multiply = Button(self, text=' * ', fg='black', bg='white',
                          command=lambda: self.pressHandler("*"), height=1, width=3)
        multiply.grid(row=5, column=3)

        divide = Button(self, text=' / ', fg='black', bg='white',
                        command=lambda: self.pressHandler("/"), height=1, width=3)
        divide.grid(row=6, column=3)

        equal = Button(self, text=' = ', fg='black', bg='white',
                       command=self.equalHandler, height=1, width=3)
        equal.grid(row=7, column=3)

        plusequal = Button(self, text=' += ', fg='black', bg='white',
                       command=self.plusEqualHandler, height=1, width=3)
        plusequal.grid(row=7, column=2)

        clear = Button(self, text='C', fg='black', bg='white',
                       command=self.clear, height=1, width=3)
        clear.grid(row=3, column=0)

        Decimal = Button(self, text='.', fg='black', bg='white',
                         command=lambda: self.pressHandler('.'), height=1, width=3)
        Decimal.grid(row=7, column=1)

        root = Button(self, text='√x', fg='black', bg='white',
                       command=self.rootHandler, height=1, width=3)
        root.grid(row=3, column=1)

        square = Button(self, text='x^2', fg='black', bg='white',
                       command=self.squareHandler, height=1, width=3)
        square.grid(row=3, column=2)
        MC = Button(self, text='MC', fg='black', bg='white',command=self.MCHandler, height=1, width=3)
      
        MC.grid(row=1, column=0)
        
        MPlus = Button(self, text='M+', fg='black', bg='white',
                       command=self.MplusHandler, height=1, width=3)
        MPlus.grid(row=1, column=1)

        MR = Button(self, text='M-', fg='black', bg='white',
                       command=self.MminusHandler, height=1, width=3)
        MR.grid(row=1, column=2)

        MMinus = Button(self, text='MR', fg='black', bg='white',
                       command=self.MRHandler, height=1, width=3)
        MMinus.grid(row=1, column=3)

class Mortgage(Frame):

    def __init__(self, parent):
        Frame.__init__(self,parent)
        self.configure(background="white", padx=10, pady=10)
        self.makeWidgets()

    def makeWidgets(self):
        Label(self, bg="white", text="Loan Amount").grid(row=1,
                                               column=1, sticky=W)
        Label(self, bg="white", text="Annual Interest Rate").grid(row=2,
                                                        column=1, sticky=W)
        Label(self, bg="white", text="Loan Terms").grid(row=3,
                                                   column=1, sticky=W)
        Label(self, bg="white", text="Monthly Payment").grid(row=4,
                                                   column=1, sticky=W)
                                                   
        Label(self, bg="white", text="Total Payment").grid(row=5,
                                                 column=1, sticky=W)
        # insert data
        self.annualInterestRateVar = StringVar()
        Entry(self, textvariable=self.annualInterestRateVar,
              justify=RIGHT).grid(row=1, column=2)
        self.numberOfYearsVar = StringVar()

        Entry(self, textvariable=self.numberOfYearsVar,
              justify=RIGHT).grid(row=2, column=2)
        self.loanAmountVar = StringVar()

        Entry(self, textvariable=self.loanAmountVar,
              justify=RIGHT).grid(row=3, column=2)
        self.monthlyPaymentVar = StringVar()
        lblMonthlyPayment = Label(self, bg="white", textvariable=self.monthlyPaymentVar).grid(row=4,
                                                                                    column=2, sticky=E)

        self.totalPaymentVar = StringVar()
        lblTotalPayment = Label(self, bg="white", textvariable=self.totalPaymentVar).grid(row=5,
                                                                                column=2, sticky=E)


        btComputePayment = Button(self, bg="white", text="Compute mortgate",
                                  command=self.calculateYourPayment).grid(
            row=6, column=1, sticky=E)
     

    def calculateYourPayment(self):
        #Credit to >> https://stackoverflow.com/questions/55505289/question-about-tkinter-annualinterestrate-is-not-defined

        monthlyPayment = self.getMonthlyPayment(
            float(self.loanAmountVar.get()),
            float(self.annualInterestRateVar.get()) / 1200,
            int(self.numberOfYearsVar.get()))

        self.monthlyPaymentVar.set(format(monthlyPayment, '10.2f'))
        totalPayment = float(self.monthlyPaymentVar.get()) * \
            12 * int(self.numberOfYearsVar.get())

        self.totalPaymentVar.set(format(totalPayment, '10.2f'))

    def getMonthlyPayment(self, loanAmount, monthlyInterestRate, numberOfYears):
        
        monthlyPayment = loanAmount * monthlyInterestRate / (1 - 1 / (1 + monthlyInterestRate) ** (numberOfYears * 12))
        return monthlyPayment
       


root = Tk()
root.title("tk")  
root.configure(background="white", padx=10, pady=10) 
mortgage = Mortgage(root)
calculator = Calculator(root)
calculator.pack(side=RIGHT)
mortgage.pack(side=LEFT)
root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-28-ed2fd555d0dc> in <module>
#     270
#     271
# --> 272 root = Tk()
#     273 root.title("tk")
#     274 root.configure(background="white", padx=10, pady=10)
#
# /usr/lib/python3.6/tkinter/__init__.py in __init__(self, screenName, baseName, className, useTk, sync, use)
#    2021                 baseName = baseName + ext
#    2022         interactive = 0
# -> 2023         self.tk = _tkinter.create(screenName, baseName, className, interactive, wantobjects, useTk, sync, use)
#    2024         if useTk:
#    2025             self._loadtk()
#
# TclError: no display name and no $DISPLAY environment variable

# %% [markdown]
# # Question 5
#
# Write function collatz() that takes a positive integer x as input and prints the Collatz sequence starting at x. A Collatz sequence is obtained by repeatedly applying this rule to the previous number x in the sequence:
# x = {	  /2
# 	3  +1
#
# Your function should stop when the sequence gets to number 1. Your implementation must be recursive, without any loops.
#
# >>>	collatz(1)
# 1
# >>>	collatz(10)
# 10
# 5
# 16
# 8
# 4
# 2
# 1

# %%
def collatz(n):
    # Looping till n becomes 1
    while(not n==1):
        # Checking if n is even
        if(n%2==0):
            # Making n to its half
            n=n//2
        # Checking if n is even
        else:
            # Changing value of n to 2n+1
            n=3*n+1
        # Printing value of n
        print(n)


# Reading input from user
n = int(input("Please enter a positive integer: "))
# Making call to collatz function
collatz(n)
# Out:
# Please enter a positive integer: 10
# 5
# 16
# 8
# 4
# 2
# 1

# %% [markdown]
# # Question 6
# Write a recursive method binary() that takes a non-negative integer n and prints the binary representation of integer n.
#
# >>>	binary(0)
# 0
# >>>	binary(1)
# 1
# >>>	binary(3)
# 11
#
# >>>	binary(9)
# 1001

# %%
#My reference 
# I solved this question in 2 ways depending on this question
#https://stackoverflow.com/questions/699866/python-int-to-binary-string

def binary(integer):
    if integer >= 0:
        return bin(integer)[2:].zfill(1)
    else:
        return bin(2**1 + integer)[2:]
    
    
    
#Another solution >>

def binaryMethod2(x):
    if(x==0):
        print(0)
        return
    binary = "" 
    while(x>0):
        binary = binary+str(x%2)
        x = x//2
    print(binary)

binary (0)
binary (1)
binary (3)
binary (9)

binaryMethod2(9)
# Out:
# 1001

# %% [markdown]
# # Question 7
#
# Implement a class named HeadingParser that can be used to parse an HTML document, and retrieve and print all the headings in the document. You should implement your class as a subclass of HTMLParser, defined in Standard Library module html.parser. When fed a string containing HTML code, your class should print the headings, one per line and in the order in which they appear in the document. Each heading should be indented as follows: an h1 heading should have indentation 0, and h2 heading should have indentation 1, etc. Test your implementation using w3c.html.

# %%
from html.parser import HTMLParser

class HeadingParser(HTMLParser):
    
    def __init__(self):
        self.start_tag = ""
        HTMLParser.__init__(self)
    def dataHandler(self, data):
        if(self.start_tag=='h1'):
            print(data)
        if(self.start_tag=='h2'):
            print("\t"+data)
        if(self.start_tag=='h3'):
            print("\t\t"+data)
        if(self.start_tag=='h4'):
            print("\t\t\t"+data)
        if(self.start_tag=='h5'):
            print("\t\t\t\t"+data)
        if(self.start_tag=='h6'):
            print("\t\t\t\t\t\t"+data)
        self.start_tag = ""

    def handle_starttag(self, tag, attrs):
        self.start_tag = tag


infile = open('w3c.html')
content = infile.read()
infile.close()
hp = HeadingParser()
hp.feed(content)

# %% [markdown]
# # Question 8
#
# Implement recursive function webdir() that takes as input: a URL (as a string) and non-negative integers depth and indent. Your function should visit every web page reachable from the starting URL web page in depth clicks or less, and print each web page's URL. As shown below, indentation, specified by indent, should be used to indicate the depth of a URL.
#
# >>>
# webdir('http://reed.cs.depaul.edu/lperkovic/csc242/test1.html'
#
# ,	2, 0) http://reed.cs.depaul.edu/lperkovic/csc242/test1.html
#
# http://reed.cs.depaul.edu/lperkovic/csc242/test2.html
# http://reed.cs.depaul.edu/lperkovic/csc242/test4.html
# http://reed.cs.depaul.edu/lperkovic/csc242/test3.html
# http://reed.cs.depaul.edu/lperkovic/csc242/test4.html

# %%
from bs4 import BeautifulSoup, SoupStrainer
import httplib2


def getLinks(url):
    res = []
    http = httplib2.Http()
    status, response = http.request(url)

    for link in BeautifulSoup(response, parse_only=SoupStrainer('a'), features="html.parser"):
        if link.has_attr('href'):
            if link['href'][:5] == "http:" or link['href'][:5] == "https":
                res.append(link['href'])

    return res

def webdir(url, depth, indent):
    
    print(indent*" " + url)

    if depth == 0:
        return

    for i in getLinks(url):
        webdir(i, depth-1, indent+1)
        

webdir("https://www.bbc.com", 2, 0)
# Out:
# https://www.bbc.com
#  https://www.bbc.co.uk
#   https://www.bbc.co.uk
#   https://www.bbc.co.uk/accessibility/
#   https://account.bbc.com/account
#   https://www.bbc.co.uk
#   https://www.bbc.co.uk/news
#   https://www.bbc.co.uk/sport
#   https://www.bbc.co.uk/weather
#   https://www.bbc.co.uk/iplayer
#   https://www.bbc.co.uk/sounds
#   https://www.bbc.co.uk/cbbc
#   https://www.bbc.co.uk/cbeebies
#   https://www.bbc.co.uk/food
#   https://www.bbc.co.uk/bitesize
#   https://www.bbc.co.uk/arts
#   https://www.bbc.co.uk/taster
#   https://www.bbc.co.uk/news/localnews
#   https://www.bbc.co.uk/bbcthree
#   https://search.bbc.co.uk/search
#   https://www.bbc.co.uk/sport/live/football/52937365
#   https://www.bbc.co.uk/bbcthree/article/5495f587-974f-4ea9-99c1-1917433c7b42
#   https://www.bbc.co.uk/news/world-us-canada-53118721
#   https://www.bbc.co.uk/news/entertainment-arts-53120390
#   https://www.bbc.co.uk/sport/football/53120245
#   https://www.bbc.co.uk/programmes/p08gkgcv
# ...

# %% [markdown]
# Question 9
#
# Write SQL queries on the below database table that return:
# a)	All the temperature data.
# b)	All the cities, but without repetition.
#
#
# c)	All the records for India.
# d)	All the Fall records.
#
# e)	The city, country, and season for which the average rainfall is between 200 and 400 millimeters.
#
# f)	The city and country for which the average Fall temperature is above 20 degrees, in increasing temperature order.
#
# g)	The total annual rainfall for Cairo.
# h)	The total rainfall for each season.

# %% [markdown]
# A)SELECT temperature from tablename;
# B)SELECT distinct city from tablename;
# C)select * from tablename where country='India';
# D)select * from tablename where season='Fall';
# E)select city, country, season from tablename where rainfaill >= 200
# and rainfall <= 400;
# F)select city, country from tablename where temperature>20
# order by temperature ASC;
# G)select count(rainfall) from tablename where city='Cairo';
# H)select rainfall, count(rainfall) from tablename
# group by rainfall;

# %% [markdown]
# # Question 10
#
# Suppose list words is defined as follows:
#
# >>>	words = ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']
#
# Write list comprehension expressions that use list words and generate the following lists:
#
# a)	['THE', 'QUICK', 'BROWN', 'FOX', 'JUMPS', 'OVER', 'THE', 'LAZY', 'DOG']
#
# b)	['the', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']
#
# c)	[3, 5, 5, 3, 5, 4, 3, 4, 3] (the list of lengths of words in list words).
#
# d)	[['THE', 'the', 3], ['QUICK', 'quick', 5], ['BROWN', 'brown', 5], ['FOX', 'fox', 3], ['JUMPS', 'jumps', 5], ['OVER', 'over', 4], ['THE', 'the', 3], ['LAZY', 'lazy', 4], ['DOG', 'dog', 3]] (the list containing a list for every word of list words, where each list contains the word in uppercase and lowercase and the length of the word.)
#
# e)	['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog'] (the list of words in list words containing 4 or more characters.)

# %%
words = ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']
list1 = [i.upper() for i in words]           #Question (a)
list2 = [i.lower() for i in words]           #Question (b) 
list3 = [len(i) for i in words]             #Question (c)
list4 = [[i.upper(),i.lower(),len(i)] for i in words]   #Question (d)
list5 = [i.lower() for i in words if len(i)>=4]         #Question (e)
print (list1) 
print (list2)
print (list3)
print (list4)
print (list5)
# Out:
# ['THE', 'QUICK', 'BROWN', 'FOX', 'JUMPS', 'OVER', 'THE', 'LAZY', 'DOG']
# ['the', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']
# [3, 5, 5, 3, 5, 4, 3, 4, 3]
# [['THE', 'the', 3], ['QUICK', 'quick', 5], ['BROWN', 'brown', 5], ['FOX', 'fox', 3], ['JUMPS', 'jumps', 5], ['OVER', 'over', 4], ['THE', 'the', 3], ['LAZY', 'lazy', 4], ['DOG', 'dog', 3]]
# ['quick', 'brown', 'jumps', 'over', 'lazy']
